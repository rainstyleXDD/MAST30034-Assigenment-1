# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
times = pd.read_csv('time.csv')

# %%
times
# Out:
#      Unnamed: 0        V1        V2        V3        V4        V5        V6  \
# 0             1  0.209645  0.032513  0.419961 -0.188538  0.130276  1.280050
# 1             2  0.019805  0.098634 -0.218129 -0.231884  0.091019  0.853786
# 2             3  0.295816  0.128396  0.095388 -0.021899 -0.040230  0.740067
# 3             4  0.160321 -0.005046  0.174674 -0.253295  0.225988  1.776928
# 4             5  0.259600  0.205301  0.589061 -0.153148 -0.079441  0.786248
# ..          ...       ...       ...       ...       ...       ...       ...
# 235         236 -0.054225 -0.041602 -1.175730  0.408454 -0.175613 -1.181497
# 236         237 -0.277136 -0.031808 -1.338801  0.423201 -0.225495 -1.614907
# 237         238 -0.229390  0.017122 -0.943100  0.352579 -0.214049 -1.763419
# 238         239  0.008817  0.046307 -0.343766  0.230702 -0.217219 -1.636538
# 239         240 -0.581455 -0.007363 -1.092607  0.099161 -0.053600 -1.232384
#
# ...

# %%
times = times.iloc[: , 1:]

# %%
time_serice = sns.lineplot(data = times, legend=False)
time_serice.figure.savefig("time_serice.png")
